# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

chrome_options = Options()
chrome_options.add_argument("--incognito")
chrome_options.add_argument("--window-size=1920x1080")
driver = webdriver.Chrome()

url = "https://tiki.vn/laptop/c8095?src=c.1846.hamburger_menu_fly_out_banner"
driver.get(url)

# %%
elements = driver.find_elements_by_css_selector(".name")
product = [el.text for el in elements]
elements = driver.find_elements_by_css_selector(".product-item")
link = [el.get_attribute("href") for el in elements]
elements = driver.find_elements_by_css_selector('.price-discount__price')
sale = [el.text for el in elements]

# %%
item = {"Sản phẩm": product, 'link':link, 'Giá':sale}

# %%
import pandas as pd

a = pd.DataFrame.from_dict(item)
a
# Out:
#                                              Sản phẩm  \
# 0   AdBàn phím cho Acer Aspire 4210 4520 4710 5220...
# 1   Máy Tính Xách Tay Laptop Huawei Matebook D15 (...
# 2   Apple MacBook Pro 2020 M1 - 13 Inchs (Apple M1...
# 3
# 4   Laptop Dell Vostro 3405 V4R53500U003W(Ryzen 5-...
# ..                                                ...
# 67
# 68  Laptop HP Gaming VICTUS 16-e0177AX 4R0U9PA (AM...
# 69  Laptop Acer Nitro 5 AN515 57 50FT i5 11400H/16...
# 70  Microsoft Surface Laptop 2 - Core i5-8250U/RAM...
# 71
#
#                                                  link           Giá
# 0   https://tka.tiki.vn/pixel?CLICK=&data=djAwMRsD...     152.000 ₫
# 1   https://tiki.vn/may-tinh-xach-tay-laptop-huawe...  13.990.000 ₫
# 2   https://tiki.vn/apple-macbook-pro-2020-m1-13-i...  33.490.000 ₫
# 3   https://tiki.vn/apple-macbook-air-2020-m1-13-i...
# 4   https://tiki.vn/laptop-dell-vostro-3405-v4r535...  16.490.000 ₫
# ..                                                ...           ...
# ...

# %%
elements = driver.find_elements_by_css_selector(".info")
b =[el.text for el in elements]
b
# Out:
# ['AdBàn phím cho Acer Aspire 4210 4520 4710 5220 5310 5720 5235 6920 Trắng Hàng Mới 100%\n152.000 ₫',
#  'Máy Tính Xách Tay Laptop Huawei Matebook D15 (8GB/256GB) Share | Màn Hình HUAWEI Fullview | | HUAWEI Phím Nguồn Kết Hợp Bảo Mật Vân Tay | Hàng Chính Hãng\nĐã bán 143\n13.990.000 ₫\nTrả góp',
#  'Apple MacBook Pro 2020 M1 - 13 Inchs (Apple M1/ 8GB/ 256GB) - Hàng Chính Hãng\n33.490.000 ₫\n-4%',
#  '',
#  'Laptop Dell Vostro 3405 V4R53500U003W(Ryzen 5-3500U/8GB/512GB PCIE/14.0 FHD/WIN 10/ĐEN) - Hàng Chính Hãng\nĐã bán 8\n16.490.000 ₫\n-13%\nTrả góp',
#  'Microsoft Surface Pro X (13/ SQ1TM/ 8GB/ 128GB SSD/ WiFi + 4G LTE/ Black) - Hàng Nhập Khẩu\nĐã bán 14\n23.500.000 ₫',
#  'Laptop Dell Vostro 3405 V4R53500U001W (Ryzen 5-3500U/4GB/256GB PCIE/14.0 FHD/WIN 10/ĐEN) - Hàng Chính Hãng\nĐã bán 6\n14.790.000 ₫\n-8%',
#  '',
# ...
